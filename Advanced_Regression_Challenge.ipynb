# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

import math
import warnings

from IPython.display import display
from sklearn import linear_model
import statsmodels.formula.api as smf

import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Display preferences.
# %matplotlib inline
pd.options.display.float_format = '{:.3f}'.format

# Suppress annoying harmless error.
warnings.filterwarnings(
    action="ignore",
    module="scipy",
    message="^internal gelsd"
)

# %%
df = pd.read_csv('~/New_York.csv', header=4, skipfooter=3)
df.head()
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#    3                      City  Population  Violent\ncrime  \
# 0  4             Adams Village        1861               0
# 1  5  Addison Town and Village        2577               3
# 2  6             Akron Village        2846               3
# 3  7                    Albany       97956             791
# 4  8            Albion Village        6388              23
#
#    Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1  \
# 0                                       0                           nan
# 1                                       0                           nan
# 2                                       0                           nan
# 3                                       8                           nan
# 4                                       0                           nan
#
#    Rape\n(legacy\ndefinition)2  Robbery  Aggravated\nassault  Property\ncrime  \
# 0                            0        0                    0               12
# 1                            0        0                    3               24
# 2                            0        0                    3               16
# 3                           30      227                  526             4090
# 4                            3        4                   16              223
#
#    Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft  Arson3
# 0         2               10                      0   0.000
# 1         3               20                      1   0.000
# 2         1               15                      0   0.000
# 3       705             3243                    142     nan
# 4        53              165                      5     nan

# %%
df.columns = ['List', 'City', 'Population', 'Violent crime', 'Murder', 'Rape1', 'Rape2', 'Robbery', 'Assault', 'Property crime', 'Burglary', 'Larceny', 'Car theft', 'Arson']

# %%
df.head()
# Out:
#    List                      City  Population  Violent crime  Murder  Rape1  \
# 0     4             Adams Village        1861              0       0    nan
# 1     5  Addison Town and Village        2577              3       0    nan
# 2     6             Akron Village        2846              3       0    nan
# 3     7                    Albany       97956            791       8    nan
# 4     8            Albion Village        6388             23       0    nan
#
#    Rape2  Robbery  Assault  Property crime  Burglary  Larceny  Car theft  \
# 0      0        0        0              12         2       10          0
# 1      0        0        3              24         3       20          1
# 2      0        0        3              16         1       15          0
# 3     30      227      526            4090       705     3243        142
# 4      3        4       16             223        53      165          5
#
#    Arson
# 0  0.000
# 1  0.000
# 2  0.000
# 3    nan
# 4    nan

# %%
df.drop(['List'], axis=1)
# Out:
#                            City  Population  Violent crime  Murder  Rape1  \
# 0                 Adams Village        1861              0       0    nan
# 1      Addison Town and Village        2577              3       0    nan
# 2                 Akron Village        2846              3       0    nan
# 3                        Albany       97956            791       8    nan
# 4                Albion Village        6388             23       0    nan
# 5                Alfred Village        4089              5       0    nan
# 6              Allegany Village        1781              3       0    nan
# 7                  Amherst Town      118296            107       1    nan
# 8            Amityville Village        9519              9       0    nan
# 9                     Amsterdam       18182             30       0    nan
# 10               Arcade Village        2053              0       0    nan
# 11              Ardsley Village        4523              5       0    nan
# 12            Asharoken Village         658              0       0    nan
# 13               Attica Village        2522              2       0    nan
# 14                       Auburn       27270             96       1    nan
# 15                 Avon Village        3333              1       0    nan
# 16        Baldwinsville Village        7473              5       0    nan
# 17         Ballston Spa Village        5418              8       0    nan
# 18                      Batavia       15374             57       0    nan
# 19                 Bath Village        5733             15       0    nan
# 20                 Bedford Town       17627              5       0    nan
# 21               Bethlehem Town       34243             13       0    nan
# 22                   Binghamton       46304            284       3    nan
# 23                  Black River        1410              0       0    nan
# 24          Blooming Grove Town       12001              8       0    nan
# 25              Bolivar Village        1022              1       0    nan
# 26                  Bolton Town        2325              2       0    nan
# 27            Boonville Village        2054              1       0    nan
# 28                   Brant Town        2065              4       0    nan
# 29                     Brewster        2358              0       0    nan
# ..                          ...         ...            ...     ...    ...
# 318         Tupper Lake Village        3642              3       0    nan
# 319         Tuxedo Park Village         615              0       0    nan
# 320                 Ulster Town       12195             14       0    nan
# 321                       Utica       61686            361       7    nan
# 322                 Vestal Town       27980             16       0    nan
# 323              Walden Village        6887             18       1    nan
# 324               Wallkill Town       27940             40       0    nan
# 325              Walton Village        3012              6       0    nan
# 326              Warsaw Village        3453              6       0    nan
# 327     Washingtonville Village        5828              2       0    nan
# 328  Waterford Town and Village        8392              4       0    nan
# 329            Waterloo Village        5175             11       0    nan
# 330                   Watertown       28179            109       0    nan
# 331                  Watervliet       10245             26       1    nan
# 332        Watkins Glen Village        1862              6       0    nan
# 333             Waverly Village        4337              5       0    nan
# 334    Webster Town and Village       43777             21       0    nan
# 335           Weedsport Village        1797              0       0    nan
# 336          Wellsville Village        4574             11       0    nan
# 337   Westhampton Beach Village        1732              2       0    nan
# 338            West Seneca Town       44821             35       1    nan
# 339           Whitehall Village        2604              6       0    nan
# 340                White Plains       57559             78       1    nan
# 341          Whitesboro Village        3733              4       0    nan
# 342             Whitestown Town        9141              0       0    nan
# 343               Woodbury Town       10685              3       0    nan
# 344           Woodridge Village         829              7       0    nan
# 345              Woodstock Town        5931              2       0    nan
# 346                     Yonkers      199134           1036       6    nan
# 347               Yorktown Town       36643             15       0    nan
#
#      Rape2  Robbery  Assault  Property crime  Burglary  Larceny  Car theft  \
# 0        0        0        0              12         2       10          0
# 1        0        0        3              24         3       20          1
# 2        0        0        3              16         1       15          0
# 3       30      227      526            4090       705     3243        142
# 4        3        4       16             223        53      165          5
# 5        0        3        2              46        10       36          0
# 6        0        0        3              10         0       10          0
# 7        7       31       68            2118       204     1882         32
# 8        2        4        3             210        16      188          6
# 9        0       12       18             405        99      291         15
# 10       0        0        0              39         3       35          1
# 11       0        3        2              33         4       28          1
# 12       0        0        0               2         0        2          0
# 13       0        0        2               5         0        4          1
# 14      20       22       53             859       132      721          6
# 15       0        1        0              25         3       20          2
# 16       0        1        4              88        10       77          1
# 17       0        3        5              94        16       78          0
# 18       7       13       37             559       103      454          2
# 19       1        3       11             191        32      157          2
# 20       0        1        4             156        26      127          3
# 21       0        3       10             442        50      388          4
# 22      19      101      161            2349       525     1767         57
# 23       0        0        0              14         2       12          0
# 24       1        0        7              99        20       72          7
# 25       0        0        1               4         2        2          0
# 26       0        0        2              24         4       20          0
# 27       0        0        1              20         6       14          0
# 28       0        1        3              31         9       20          2
# 29       0        0        0              13         3       10          0
# ..     ...      ...      ...             ...       ...      ...        ...
# 318      0        0        3              83        22       59          2
# 319      0        0        0               0         0        0          0
# 320      3        2        9             437        25      410          2
# 321     27      102      225            2528       449     1997         82
# 322      2        6        8             571        39      523          9
# 323      2        1       14             142        13      124          5
# 324      3       16       21             767        91      650         26
# 325      1        0        5              68        18       50          0
# 326      1        0        5              78         5       73          0
# 327      0        1        1              58         5       51          2
# 328      0        0        4              59         6       52          1
# 329      0        3        8             194        23      169          2
# 330     12       16       81            1165       169      953         43
# 331      3       11       11             242        58      163         21
# 332      0        0        6              92        10       80          2
# 333      0        1        4              54         9       41          4
# 334      2        3       16             469       101      361          7
# 335      0        0        0              25         5       20          0
# 336      1        0       10             164        32      129          3
# 337      0        0        2              44         4       37          3
# 338      1        9       24             896       166      710         20
# 339      0        0        6              62        12       49          1
# 340      3       28       46            1232        77     1134         21
# 341      0        0        4              36        14       21          1
# 342      0        0        0              77        13       61          3
# 343      0        2        1             541         9      529          3
# 344      0        0        7              17         8        9          0
# 345      0        0        2              58        13       45          0
# 346     25      390      615            2368       470     1662        236
# 347      0        2       13             334        45      287          2
#
#      Arson
# 0    0.000
# 1    0.000
# 2    0.000
# 3      nan
# 4      nan
# 5      nan
# 6    0.000
# 7    3.000
# 8    1.000
# 9    0.000
# 10   0.000
# 11   0.000
# 12   0.000
# 13   0.000
# 14     nan
# 15     nan
# 16   0.000
# 17   1.000
# 18     nan
# 19   2.000
# 20     nan
# 21     nan
# 22     nan
# 23   0.000
# 24     nan
# 25   0.000
# 26   0.000
# 27   0.000
# 28   0.000
# 29   0.000
# ..     ...
# 318    nan
# 319  0.000
# 320    nan
# 321    nan
# 322    nan
# 323    nan
# 324  1.000
# 325    nan
# 326  0.000
# 327  0.000
# 328  0.000
# 329    nan
# 330    nan
# 331    nan
# 332    nan
# 333    nan
# 334    nan
# 335  0.000
# 336  1.000
# 337  0.000
# 338  0.000
# 339    nan
# 340    nan
# 341  0.000
# 342  0.000
# 343    nan
# 344  0.000
# 345    nan
# 346 10.000
# 347    nan
#
# [348 rows x 13 columns]

# %%
NY = pd.DataFrame(df)

# %%
NY = NY.drop("Rape1",axis=1)

# %%
NY = NY.drop("Arson",axis=1)

# %%
#Remove New York City from the data - NYC is an outlier
NY = NY[NY.City != "New York"]

# %%
NY['Murder1'] = np.where(NY['Murder'] > NY['Murder'].mean(), 1,0)

# %%
NY['Robbery1'] = np.where(NY['Robbery'] >0, 1, 0)

# %%
NY['Violent crime1'] = np.where(NY['Violent crime'] >0, 1, 0)

# %%
NY._get_numeric_data().corr()
# Out:
#                 List  Population  Violent crime  Murder  Rape2  Robbery  \
# List           1.000       0.047          0.022   0.032  0.019    0.016
# Population     0.047       1.000          0.829   0.756  0.797    0.816
# Violent crime  0.022       0.829          1.000   0.955  0.962    0.994
# Murder         0.032       0.756          0.955   1.000  0.946    0.963
# Rape2          0.019       0.797          0.962   0.946  1.000    0.949
# Robbery        0.016       0.816          0.994   0.963  0.949    1.000
# Assault        0.025       0.835          0.997   0.938  0.958    0.983
# Property crime 0.017       0.887          0.944   0.917  0.949    0.933
# Burglary       0.021       0.820          0.971   0.956  0.974    0.964
# Larceny        0.015       0.901          0.913   0.881  0.921    0.898
# Car theft      0.021       0.828          0.987   0.959  0.960    0.989
# Murder1        0.126       0.503          0.406   0.408  0.403    0.378
# Robbery1       0.035       0.344          0.168   0.132  0.189    0.154
# Violent crime1 0.060       0.201          0.090   0.068  0.104    0.078
#
#                 Assault  Property crime  Burglary  Larceny  Car theft  \
# List              0.025           0.017     0.021    0.015      0.021
# Population        0.835           0.887     0.820    0.901      0.828
# Violent crime     0.997           0.944     0.971    0.913      0.987
# Murder            0.938           0.917     0.956    0.881      0.959
# Rape2             0.958           0.949     0.974    0.921      0.960
# Robbery           0.983           0.933     0.964    0.898      0.989
# Assault           1.000           0.942     0.964    0.913      0.977
# Property crime    0.942           1.000     0.977    0.995      0.949
# Burglary          0.964           0.977     1.000    0.950      0.976
# Larceny           0.913           0.995     0.950    1.000      0.916
# Car theft         0.977           0.949     0.976    0.916      1.000
# Murder1           0.422           0.443     0.402    0.458      0.368
# Robbery1          0.176           0.267     0.197    0.297      0.164
# Violent crime1    0.097           0.147     0.108    0.164      0.087
#
#                 Murder1  Robbery1  Violent crime1
# List              0.126     0.035           0.060
# Population        0.503     0.344           0.201
# Violent crime     0.406     0.168           0.090
# Murder            0.408     0.132           0.068
# Rape2             0.403     0.189           0.104
# Robbery           0.378     0.154           0.078
# Assault           0.422     0.176           0.097
# Property crime    0.443     0.267           0.147
# Burglary          0.402     0.197           0.108
# Larceny           0.458     0.297           0.164
# Car theft         0.368     0.164           0.087
# Murder1           1.000     0.311           0.166
# Robbery1          0.311     1.000           0.508
# Violent crime1    0.166     0.508           1.000

# %% [markdown]
# ## Logistic Regression

# %%
# Declare a logistic regression classifier.
# Parameter regularization coefficient C.
lr = LogisticRegression(C=1e9)
X = NY[['Murder1', 'Robbery1']]
y = NY['Violent crime1']


# Fit the model.
fit = lr.fit(X, y)

# Display.
print('Coefficients')
print(fit.coef_)
print(fit.intercept_)
pred_y_sklearn = lr.predict(X)

print('\n Accuracy')
print(pd.crosstab(pred_y_sklearn, y))

print('\n Percentage accuracy')
print(lr.score(X, y))
# Out:
# Coefficients
# [[ 7.00336739 11.19727277]]
# [0.53408257]
#
#  Accuracy
# Violent crime1   0    1
# row_0
# 1               51  296
#
#  Percentage accuracy
# 0.8530259365994236

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape
# Out:
# (232, 2)

# %%
print(X_train.shape) 
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (232, 2)
# (115, 2)
# (232,)
# (115,)

# %%
ridgeregr.fit(X_train, y_train)
print('R²:')
print(ridgeregr.score(X_test, y_test))
# Out:
# R²:
# -1.976635763606006

# %% [markdown]
# ## Lasso Regression

# %%
lass = linear_model.Lasso(alpha=.35)
lassfit = lass.fit(X_train, y_train)
print('R²:')
print(lass.score(X_test, y_test))
# Out:
# R²:
# -0.02568726315185343

# %% [markdown]
# The best fit model is the vanilla regression. This might be becasue ridge regression works best on models that are complex.  This model is not very complex.  Ridge also works best when features become mulitcolinear.  In this example, features are correlated with one another but using ridge regression did not work at all and produced a terrible R2.  Additionally there is no indication that the vanilla regression is overfit.  Lasso Regression works best when dealing with thousands or hundred of thousands of predictors and need to optimize processor time or when you want to arrive at a simplier solution that is easier to interpret.  In this case the data set has a small amount of features therefore Lasso produced a poor result.
